# %% [markdown]
# <a href="https://colab.research.google.com/github/Mandeep-Andey/ML-Project1/blob/main/ML_Project_1_Problem_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Hardcoded test content
test_content = """
The quick brown fox jumps over a lazy dog
Waltz, bad nymph, for quick jigs vex
Glib jocks quiz nymph to vex dwarf
Sphinx of black quartz, judge my vow
How vexingly quick daft zebras jump
The five boxing wizards jump quickly
Jackdaws love my big sphinx of quartz
Pack my box with five dozen liquor jugs
Waltz, bad nymph, for quick jigs vex
Quick zephyrs blow, vexing daft Jim
Sphinx of black quartz, judge my vow
Two driven jocks help fax my big quiz
Five quacking zephyrs jolt my wax bed
The five boxing wizards jump quickly
Pack my box with five dozen liquor jugs
The quick brown fox jumps over the lazy dog
Jinxed wizards pluck ivy from the big quilt
Crazy Fredrick bought many very exquisite opal jewels
We promptly judged antique ivory buckles for the next prize
A mad boxer shot a quick, gloved jab to the jaw of his dizzy opponent
Jaded zombies acted quaintly but kept driving their oxen forward
The job requires extra pluck and zeal from every young wage earner
"""

# Convert test content to a file-like object
file_like = test_content.strip().splitlines()

# Step 2
letter_freq = {}

# Step 3
alpha_freq = np.zeros(26, dtype=int)

# Step 4
for line in file_like:
    # Step 4.1
    line = line.lower()

    # Step 4.2
    for char in line:
        # Step 4.3
        if char.isalpha():
            # Update letter_freq
            letter_freq[char] = letter_freq.get(char, 0) + 1

            # Update alpha_freq
            alpha_freq[ord(char) - ord('a')] += 1

# Step 6
print("Letter Frequencies:")
print(letter_freq)

# Step 7
plt.bar(range(26), alpha_freq, tick_label=[chr(i + ord('a')) for i in range(26)])
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Letter Frequencies Histogram')
plt.show()
# Out:
# Letter Frequencies:
# {'t': 36, 'h': 25, 'e': 63, 'q': 22, 'u': 38, 'i': 56, 'c': 23, 'k': 22, 'b': 24, 'r': 40, 'o': 50, 'w': 22, 'n': 28, 'f': 22, 'x': 22, 'j': 23, 'm': 22, 'p': 25, 's': 25, 'v': 22, 'a': 44, 'l': 26, 'z': 23, 'y': 27, 'd': 30, 'g': 23}
